# %%
# Import dependencies
from citipy import citipy
import pandas as pd
import numpy as np
import json 
import requests

from config import weather_api_key

# %%
# Create a new set of 2,000 random latitudes and longitudes
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Unpack lat_lngs zip object into a list. This way, we only need to create a set of random latitudes and longitudes once. 
lat_lngs = zip(lats, lngs)
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Get the nearest city using the citipy module
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 736

# %%
# Perform an API call with the OpenWeatherMap
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_country = city_weather["sys"]["country"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        description = city_weather['weather'][0]['description']
        
        # Append the city information to the city_data list
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description":description })

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | saint george
# Processing Record 2 of Set 1 | la palma
# Processing Record 3 of Set 1 | bilibino
# Processing Record 4 of Set 1 | durres
# Processing Record 5 of Set 1 | port macquarie
# Processing Record 6 of Set 1 | mataura
# Processing Record 7 of Set 1 | tuktoyaktuk
# Processing Record 8 of Set 1 | saint-philippe
# Processing Record 9 of Set 1 | pisco
# Processing Record 10 of Set 1 | cape town
# Processing Record 11 of Set 1 | sotnikovskoye
# Processing Record 12 of Set 1 | charters towers
# Processing Record 13 of Set 1 | kapaa
# Processing Record 14 of Set 1 | chapaevsk
# Processing Record 15 of Set 1 | new norfolk
# Processing Record 16 of Set 1 | rikitea
# Processing Record 17 of Set 1 | vaini
# Processing Record 18 of Set 1 | kulebaki
# Processing Record 19 of Set 1 | abu dhabi
# Processing Record 20 of Set 1 | sitka
# Processing Record 21 of Set 1 | ribeira grande
# Processing Record 22 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 23 of Set 1 | gat
# Processing Record 24 of Set 1 | port elizabeth
# Processing Record 25 of Set 1 | tomatlan
# Processing Record 26 of Set 1 | albany
# Processing Record 27 of Set 1 | valdivia
# Processing Record 28 of Set 1 | atar
# Processing Record 29 of Set 1 | hilo
# Processing Record 30 of Set 1 | busselton
# Processing Record 31 of Set 1 | iskateley
# Processing Record 32 of Set 1 | punta arenas
# Processing Record 33 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 34 of Set 1 | ushuaia
# Processing Record 35 of Set 1 | cabo san lucas
# Processing Record 36 of Set 1 | barrow
# Processing Record 37 of Set 1 | halol
# Processing Record 38 of Set 1 | hofn
# Processing Record 39 of Set 1 | aklavik
# Processing Record 40 of Set 1 | sao joao do piaui
# Processing Record 41 of Set 1 | vestmannaeyjar
# Processing Record 42 of Set 1 | kavieng
# Processing Record 43 of Set 1 | adet
# Processing Record 44 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 45 of Set 1 | sibolga
# Processing Record 46 of Set 1 | nikolskoye
# Processing Record 47 of Set 1 | carutapera
# Processing Record 48 of Set 1 | yellowknife
# Processing Record 49 of Set 1 | dikson
# Processing Record 50 of Set 1 | east london
# Processing Record 1 of Set 2 | aleksandrovskoye
# Processing Record 2 of Set 2 | el balyana
# City not found. Skipping...
# Processing Record 3 of Set 2 | temaraia
# City not found. Skipping...
# Processing Record 4 of Set 2 | haren
# Processing Record 5 of Set 2 | narsaq
# Processing Record 6 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 7 of Set 2 | victoria
# Processing Record 8 of Set 2 | rabaul
# Processing Record 9 of Set 2 | maykain
# City not found. Skipping...
# Processing Record 10 of Set 2 | oktyabrskoye
# Processing Record 11 of Set 2 | fukue
# Processing Record 12 of Set 2 | arraial do cabo
# Processing Record 13 of Set 2 | kaduy
# Processing Record 14 of Set 2 | hermanus
# Processing Record 15 of Set 2 | port alfred
# Processing Record 16 of Set 2 | hobart
# Processing Record 17 of Set 2 | carnarvon
# Processing Record 18 of Set 2 | leningradskiy
# Processing Record 19 of Set 2 | puerto ayora
# Processing Record 20 of Set 2 | bluff
# Processing Record 21 of Set 2 | bathsheba
# Processing Record 22 of Set 2 | jamestown
# Processing Record 23 of Set 2 | mayor pablo lagerenza
# Processing Record 24 of Set 2 | carmen
# Processing Record 25 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 26 of Set 2 | lampang
# Processing Record 27 of Set 2 | wanning
# Processing Record 28 of Set 2 | provideniya
# Processing Record 29 of Set 2 | meadow lake
# Processing Record 30 of Set 2 | atuona
# Processing Record 31 of Set 2 | pangnirtung
# Processing Record 32 of Set 2 | thompson
# Processing Record 33 of Set 2 | khani
# Processing Record 34 of Set 2 | kaitangata
# Processing Record 35 of Set 2 | smithers
# Processing Record 36 of Set 2 | aranos
# Processing Record 37 of Set 2 | soyo
# Processing Record 38 of Set 2 | ostrovnoy
# Processing Record 39 of Set 2 | netrakona
# Processing Record 40 of Set 2 | mbuji-mayi
# Processing Record 41 of Set 2 | pevek
# Processing Record 42 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 43 of Set 2 | talaya
# Processing Record 44 of Set 2 | anloga
# Processing Record 45 of Set 2 | salalah
# Processing Record 46 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 47 of Set 2 | samarai
# Processing Record 48 of Set 2 | bambous virieux
# Processing Record 49 of Set 2 | cidreira
# Processing Record 50 of Set 2 | hasaki
# Processing Record 1 of Set 3 | alice springs
# Processing Record 2 of Set 3 | chokurdakh
# Processing Record 3 of Set 3 | butaritari
# Processing Record 4 of Set 3 | avarua
# Processing Record 5 of Set 3 | fortuna
# Processing Record 6 of Set 3 | baykit
# Processing Record 7 of Set 3 | hithadhoo
# Processing Record 8 of Set 3 | chuy
# Processing Record 9 of Set 3 | clyde river
# Processing Record 10 of Set 3 | alofi
# Processing Record 11 of Set 3 | esperance
# Processing Record 12 of Set 3 | searcy
# Processing Record 13 of Set 3 | airai
# Processing Record 14 of Set 3 | poum
# Processing Record 15 of Set 3 | phaltan
# Processing Record 16 of Set 3 | kodiak
# Processing Record 17 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 18 of Set 3 | talnakh
# Processing Record 19 of Set 3 | praia da vitoria
# Processing Record 20 of Set 3 | husavik
# Processing Record 21 of Set 3 | nuuk
# Processing Record 22 of Set 3 | turka
# Processing Record 23 of Set 3 | cheshunt
# Processing Record 24 of Set 3 | santa rosa
# Processing Record 25 of Set 3 | eydhafushi
# Processing Record 26 of Set 3 | san quintin
# Processing Record 27 of Set 3 | mitu
# Processing Record 28 of Set 3 | carballo
# Processing Record 29 of Set 3 | maniitsoq
# Processing Record 30 of Set 3 | castro
# Processing Record 31 of Set 3 | asau
# Processing Record 32 of Set 3 | oksovskiy
# Processing Record 33 of Set 3 | saskylakh
# Processing Record 34 of Set 3 | namatanai
# Processing Record 35 of Set 3 | camapua
# Processing Record 36 of Set 3 | tiksi
# Processing Record 37 of Set 3 | felidhoo
# City not found. Skipping...
# Processing Record 38 of Set 3 | bud
# Processing Record 39 of Set 3 | qaanaaq
# Processing Record 40 of Set 3 | saint anthony
# Processing Record 41 of Set 3 | port lincoln
# Processing Record 42 of Set 3 | kahului
# Processing Record 43 of Set 3 | dinard
# Processing Record 44 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 45 of Set 3 | safaga
# Processing Record 46 of Set 3 | saint-pierre
# Processing Record 47 of Set 3 | sao caetano de odivelas
# Processing Record 48 of Set 3 | ancud
# Processing Record 49 of Set 3 | ankazoabo
# Processing Record 50 of Set 3 | barra do garcas
# Processing Record 1 of Set 4 | nyurba
# Processing Record 2 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 3 of Set 4 | palabuhanratu
# City not found. Skipping...
# Processing Record 4 of Set 4 | oranjestad
# Processing Record 5 of Set 4 | tongling
# Processing Record 6 of Set 4 | ikole
# City not found. Skipping...
# Processing Record 7 of Set 4 | wollongong
# Processing Record 8 of Set 4 | college
# Processing Record 9 of Set 4 | leh
# Processing Record 10 of Set 4 | bredasdorp
# Processing Record 11 of Set 4 | dunedin
# Processing Record 12 of Set 4 | san carlos de bariloche
# Processing Record 13 of Set 4 | yanan
# City not found. Skipping...
# Processing Record 14 of Set 4 | kalmunai
# Processing Record 15 of Set 4 | lebu
# Processing Record 16 of Set 4 | altay
# Processing Record 17 of Set 4 | marsabit
# Processing Record 18 of Set 4 | kenitra
# Processing Record 19 of Set 4 | cherskiy
# Processing Record 20 of Set 4 | shahdadpur
# Processing Record 21 of Set 4 | lata
# Processing Record 22 of Set 4 | melilla
# Processing Record 23 of Set 4 | seoul
# Processing Record 24 of Set 4 | bilma
# Processing Record 25 of Set 4 | trincomalee
# Processing Record 26 of Set 4 | lopatinskiy
# Processing Record 27 of Set 4 | bargal
# City not found. Skipping...
# Processing Record 28 of Set 4 | coquimbo
# Processing Record 29 of Set 4 | ambulu
# Processing Record 30 of Set 4 | samalaeulu
# City not found. Skipping...
# Processing Record 31 of Set 4 | port blair
# Processing Record 32 of Set 4 | le pradet
# Processing Record 33 of Set 4 | verkhoyansk
# Processing Record 34 of Set 4 | gazli
# Processing Record 35 of Set 4 | babanusah
# City not found. Skipping...
# Processing Record 36 of Set 4 | buenos aires
# Processing Record 37 of Set 4 | bollnas
# Processing Record 38 of Set 4 | varhaug
# Processing Record 39 of Set 4 | burica
# City not found. Skipping...
# Processing Record 40 of Set 4 | ginir
# Processing Record 41 of Set 4 | emerald
# Processing Record 42 of Set 4 | anadyr
# Processing Record 43 of Set 4 | hovd
# Processing Record 44 of Set 4 | lagoa
# Processing Record 45 of Set 4 | saldanha
# Processing Record 46 of Set 4 | upernavik
# Processing Record 47 of Set 4 | katsuura
# Processing Record 48 of Set 4 | ndele
# Processing Record 49 of Set 4 | mao
# Processing Record 50 of Set 4 | high level
# Processing Record 1 of Set 5 | tawang
# Processing Record 2 of Set 5 | tekeli
# Processing Record 3 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 4 of Set 5 | ipixuna
# Processing Record 5 of Set 5 | komsomolets
# Processing Record 6 of Set 5 | luderitz
# Processing Record 7 of Set 5 | pacific grove
# Processing Record 8 of Set 5 | souillac
# Processing Record 9 of Set 5 | utiroa
# City not found. Skipping...
# Processing Record 10 of Set 5 | bayji
# Processing Record 11 of Set 5 | port hardy
# Processing Record 12 of Set 5 | paamiut
# Processing Record 13 of Set 5 | halifax
# Processing Record 14 of Set 5 | verkh-usugli
# Processing Record 15 of Set 5 | mehamn
# Processing Record 16 of Set 5 | ponta do sol
# Processing Record 17 of Set 5 | hami
# Processing Record 18 of Set 5 | oga
# Processing Record 19 of Set 5 | ponnani
# Processing Record 20 of Set 5 | vitry-le-francois
# Processing Record 21 of Set 5 | shellbrook
# Processing Record 22 of Set 5 | hamilton
# Processing Record 23 of Set 5 | mercedes
# Processing Record 24 of Set 5 | byron bay
# Processing Record 25 of Set 5 | nantucket
# Processing Record 26 of Set 5 | malumfashi
# Processing Record 27 of Set 5 | havre-saint-pierre
# Processing Record 28 of Set 5 | praya
# Processing Record 29 of Set 5 | khatanga
# Processing Record 30 of Set 5 | severnyy
# Processing Record 31 of Set 5 | zheleznodorozhnyy
# Processing Record 32 of Set 5 | kuala terengganu
# Processing Record 33 of Set 5 | tuggurt
# City not found. Skipping...
# Processing Record 34 of Set 5 | apatzingan
# Processing Record 35 of Set 5 | ulladulla
# Processing Record 36 of Set 5 | homer
# Processing Record 37 of Set 5 | tadine
# Processing Record 38 of Set 5 | cravo norte
# Processing Record 39 of Set 5 | tommot
# Processing Record 40 of Set 5 | verkhnyaya inta
# Processing Record 41 of Set 5 | deputatskiy
# Processing Record 42 of Set 5 | constitucion
# Processing Record 43 of Set 5 | stornoway
# Processing Record 44 of Set 5 | bonthe
# Processing Record 45 of Set 5 | olovo
# Processing Record 46 of Set 5 | tura
# Processing Record 47 of Set 5 | nanortalik
# Processing Record 48 of Set 5 | georgetown
# Processing Record 49 of Set 5 | lebork
# Processing Record 50 of Set 5 | rocha
# Processing Record 1 of Set 6 | neiafu
# Processing Record 2 of Set 6 | bethel
# Processing Record 3 of Set 6 | sorong
# Processing Record 4 of Set 6 | litoral del san juan
# City not found. Skipping...
# Processing Record 5 of Set 6 | iqaluit
# Processing Record 6 of Set 6 | hakkari
# Processing Record 7 of Set 6 | rio cuarto
# Processing Record 8 of Set 6 | lazaro cardenas
# Processing Record 9 of Set 6 | torbay
# Processing Record 10 of Set 6 | mahebourg
# Processing Record 11 of Set 6 | coihaique
# Processing Record 12 of Set 6 | barcelona
# Processing Record 13 of Set 6 | darnah
# Processing Record 14 of Set 6 | wulanhaote
# City not found. Skipping...
# Processing Record 15 of Set 6 | komsomolskiy
# Processing Record 16 of Set 6 | longyearbyen
# Processing Record 17 of Set 6 | ilulissat
# Processing Record 18 of Set 6 | tuatapere
# Processing Record 19 of Set 6 | guerrero negro
# Processing Record 20 of Set 6 | acapulco
# Processing Record 21 of Set 6 | isangel
# Processing Record 22 of Set 6 | soure
# Processing Record 23 of Set 6 | hambantota
# Processing Record 24 of Set 6 | west wendover
# Processing Record 25 of Set 6 | grand gaube
# Processing Record 26 of Set 6 | jenison
# Processing Record 27 of Set 6 | kibala
# Processing Record 28 of Set 6 | quatre cocos
# Processing Record 29 of Set 6 | atambua
# Processing Record 30 of Set 6 | severo-kurilsk
# Processing Record 31 of Set 6 | las choapas
# Processing Record 32 of Set 6 | fevik
# Processing Record 33 of Set 6 | dudinka
# Processing Record 34 of Set 6 | bambanglipuro
# Processing Record 35 of Set 6 | clarksburg
# Processing Record 36 of Set 6 | namibe
# Processing Record 37 of Set 6 | inuvik
# Processing Record 38 of Set 6 | sorland
# Processing Record 39 of Set 6 | cedral
# Processing Record 40 of Set 6 | umzimvubu
# City not found. Skipping...
# Processing Record 41 of Set 6 | grindavik
# Processing Record 42 of Set 6 | ambilobe
# Processing Record 43 of Set 6 | salinas
# Processing Record 44 of Set 6 | chokwe
# Processing Record 45 of Set 6 | valparaiso
# Processing Record 46 of Set 6 | chama
# Processing Record 47 of Set 6 | sept-iles
# Processing Record 48 of Set 6 | kabanga
# Processing Record 49 of Set 6 | klaksvik
# Processing Record 50 of Set 6 | tyukalinsk
# Processing Record 1 of Set 7 | marv dasht
# City not found. Skipping...
# Processing Record 2 of Set 7 | marawi
# Processing Record 3 of Set 7 | dergachi
# Processing Record 4 of Set 7 | pochutla
# Processing Record 5 of Set 7 | porto murtinho
# Processing Record 6 of Set 7 | mys shmidta
# City not found. Skipping...
# Processing Record 7 of Set 7 | chimore
# Processing Record 8 of Set 7 | aden
# Processing Record 9 of Set 7 | basoko
# Processing Record 10 of Set 7 | sigmaringen
# Processing Record 11 of Set 7 | guia de isora
# Processing Record 12 of Set 7 | lishui
# Processing Record 13 of Set 7 | malmesbury
# Processing Record 14 of Set 7 | meyungs
# City not found. Skipping...
# Processing Record 15 of Set 7 | marmande
# Processing Record 16 of Set 7 | marshall
# Processing Record 17 of Set 7 | pauini
# Processing Record 18 of Set 7 | caravelas
# Processing Record 19 of Set 7 | namanyere
# Processing Record 20 of Set 7 | kaman
# Processing Record 21 of Set 7 | xinyu
# Processing Record 22 of Set 7 | eleousa
# Processing Record 23 of Set 7 | tlahualilo
# City not found. Skipping...
# Processing Record 24 of Set 7 | vanavara
# Processing Record 25 of Set 7 | hede
# Processing Record 26 of Set 7 | samusu
# City not found. Skipping...
# Processing Record 27 of Set 7 | kazachinskoye
# Processing Record 28 of Set 7 | te anau
# Processing Record 29 of Set 7 | buchanan
# Processing Record 30 of Set 7 | broome
# Processing Record 31 of Set 7 | sioux lookout
# Processing Record 32 of Set 7 | ruatoria
# City not found. Skipping...
# Processing Record 33 of Set 7 | kitsuki
# Processing Record 34 of Set 7 | erechim
# Processing Record 35 of Set 7 | celestun
# Processing Record 36 of Set 7 | camacupa
# Processing Record 37 of Set 7 | magadan
# Processing Record 38 of Set 7 | bengkulu
# Processing Record 39 of Set 7 | vung tau
# Processing Record 40 of Set 7 | codrington
# Processing Record 41 of Set 7 | muros
# Processing Record 42 of Set 7 | cockburn town
# Processing Record 43 of Set 7 | mayumba
# Processing Record 44 of Set 7 | oum hadjer
# Processing Record 45 of Set 7 | rawson
# Processing Record 46 of Set 7 | banda aceh
# Processing Record 47 of Set 7 | bam
# Processing Record 48 of Set 7 | vaitupu
# City not found. Skipping...
# Processing Record 49 of Set 7 | mar del plata
# Processing Record 50 of Set 7 | khonuu
# City not found. Skipping...
# Processing Record 1 of Set 8 | porto santo
# Processing Record 2 of Set 8 | staryy oskol
# Processing Record 3 of Set 8 | belaya gora
# Processing Record 4 of Set 8 | adrar
# Processing Record 5 of Set 8 | moreira sales
# Processing Record 6 of Set 8 | oktyabrskiy
# Processing Record 7 of Set 8 | baleshwar
# Processing Record 8 of Set 8 | acuna
# City not found. Skipping...
# Processing Record 9 of Set 8 | palivere
# Processing Record 10 of Set 8 | codajas
# Processing Record 11 of Set 8 | sungaipenuh
# Processing Record 12 of Set 8 | port-gentil
# Processing Record 13 of Set 8 | zhuhai
# Processing Record 14 of Set 8 | sestri levante
# Processing Record 15 of Set 8 | mogok
# Processing Record 16 of Set 8 | somerset east
# Processing Record 17 of Set 8 | ust-kuyga
# Processing Record 18 of Set 8 | alunitdag
# City not found. Skipping...
# Processing Record 19 of Set 8 | pemangkat
# Processing Record 20 of Set 8 | warqla
# City not found. Skipping...
# Processing Record 21 of Set 8 | san patricio
# Processing Record 22 of Set 8 | camana
# Processing Record 23 of Set 8 | teya
# Processing Record 24 of Set 8 | heze
# Processing Record 25 of Set 8 | sakakah
# Processing Record 26 of Set 8 | beno-yurt
# City not found. Skipping...
# Processing Record 27 of Set 8 | tongliao
# Processing Record 28 of Set 8 | kapuskasing
# Processing Record 29 of Set 8 | qaqortoq
# Processing Record 30 of Set 8 | kutum
# Processing Record 31 of Set 8 | cairns
# Processing Record 32 of Set 8 | laguna
# Processing Record 33 of Set 8 | valentin gomez farias
# Processing Record 34 of Set 8 | mithimna
# City not found. Skipping...
# Processing Record 35 of Set 8 | touros
# Processing Record 36 of Set 8 | nouadhibou
# Processing Record 37 of Set 8 | necochea
# Processing Record 38 of Set 8 | doka
# Processing Record 39 of Set 8 | taybad
# Processing Record 40 of Set 8 | sao joao da barra
# Processing Record 41 of Set 8 | havoysund
# Processing Record 42 of Set 8 | erzin
# Processing Record 43 of Set 8 | balakovo
# Processing Record 44 of Set 8 | faanui
# Processing Record 45 of Set 8 | cayenne
# Processing Record 46 of Set 8 | kirakira
# Processing Record 47 of Set 8 | sarwar
# Processing Record 48 of Set 8 | inta
# Processing Record 49 of Set 8 | lorengau
# Processing Record 50 of Set 8 | ahipara
# Processing Record 1 of Set 9 | megion
# Processing Record 2 of Set 9 | ryde
# Processing Record 3 of Set 9 | qom
# Processing Record 4 of Set 9 | fevralsk
# City not found. Skipping...
# Processing Record 5 of Set 9 | anaconda
# Processing Record 6 of Set 9 | sedalia
# Processing Record 7 of Set 9 | tucumcari
# Processing Record 8 of Set 9 | roches noires
# City not found. Skipping...
# Processing Record 9 of Set 9 | douentza
# Processing Record 10 of Set 9 | colares
# Processing Record 11 of Set 9 | teutonia
# Processing Record 12 of Set 9 | marsaxlokk
# Processing Record 13 of Set 9 | bousso
# Processing Record 14 of Set 9 | hanumangarh
# Processing Record 15 of Set 9 | kenai
# Processing Record 16 of Set 9 | kaohsiung
# Processing Record 17 of Set 9 | zhigansk
# Processing Record 18 of Set 9 | camopi
# Processing Record 19 of Set 9 | sao filipe
# Processing Record 20 of Set 9 | awbari
# Processing Record 21 of Set 9 | gamboula
# Processing Record 22 of Set 9 | norman wells
# Processing Record 23 of Set 9 | kunming
# Processing Record 24 of Set 9 | irtyshskiy
# Processing Record 25 of Set 9 | gunjur
# Processing Record 26 of Set 9 | natitingou
# Processing Record 27 of Set 9 | baherden
# Processing Record 28 of Set 9 | kloulklubed
# Processing Record 29 of Set 9 | assiniboia
# Processing Record 30 of Set 9 | saint-augustin
# Processing Record 31 of Set 9 | beringovskiy
# Processing Record 32 of Set 9 | san cristobal
# Processing Record 33 of Set 9 | mae sot
# Processing Record 34 of Set 9 | matameye
# City not found. Skipping...
# Processing Record 35 of Set 9 | mackay
# Processing Record 36 of Set 9 | kruisfontein
# Processing Record 37 of Set 9 | skalistyy
# City not found. Skipping...
# Processing Record 38 of Set 9 | fort nelson
# Processing Record 39 of Set 9 | port augusta
# Processing Record 40 of Set 9 | tasiilaq
# Processing Record 41 of Set 9 | tariba
# Processing Record 42 of Set 9 | chicama
# Processing Record 43 of Set 9 | geraldton
# Processing Record 44 of Set 9 | havelock
# Processing Record 45 of Set 9 | pyshma
# Processing Record 46 of Set 9 | bandarbeyla
# Processing Record 47 of Set 9 | erenhot
# Processing Record 48 of Set 9 | saint-joseph
# Processing Record 49 of Set 9 | kopong
# Processing Record 50 of Set 9 | getahovit
# Processing Record 1 of Set 10 | turochak
# Processing Record 2 of Set 10 | piedecuesta
# Processing Record 3 of Set 10 | dingle
# Processing Record 4 of Set 10 | gallup
# Processing Record 5 of Set 10 | cartagena
# Processing Record 6 of Set 10 | yaan
# Processing Record 7 of Set 10 | ngukurr
# City not found. Skipping...
# Processing Record 8 of Set 10 | mazara del vallo
# Processing Record 9 of Set 10 | aguimes
# Processing Record 10 of Set 10 | lavrentiya
# Processing Record 11 of Set 10 | mabaruma
# Processing Record 12 of Set 10 | iringa
# Processing Record 13 of Set 10 | chapleau
# Processing Record 14 of Set 10 | bowen
# Processing Record 15 of Set 10 | rio claro
# Processing Record 16 of Set 10 | puerto madryn
# Processing Record 17 of Set 10 | aswan
# Processing Record 18 of Set 10 | temiscaming
# Processing Record 19 of Set 10 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 20 of Set 10 | nome
# Processing Record 21 of Set 10 | los llanos de aridane
# Processing Record 22 of Set 10 | inverbervie
# Processing Record 23 of Set 10 | verkhneyarkeyevo
# Processing Record 24 of Set 10 | tumannyy
# City not found. Skipping...
# Processing Record 25 of Set 10 | samana
# Processing Record 26 of Set 10 | geresk
# City not found. Skipping...
# Processing Record 27 of Set 10 | madimba
# Processing Record 28 of Set 10 | ahuimanu
# Processing Record 29 of Set 10 | itarema
# Processing Record 30 of Set 10 | zyryanovsk
# Processing Record 31 of Set 10 | vostok
# Processing Record 32 of Set 10 | scottsburgh
# City not found. Skipping...
# Processing Record 33 of Set 10 | okha
# Processing Record 34 of Set 10 | kudat
# Processing Record 35 of Set 10 | urucara
# Processing Record 36 of Set 10 | griffith
# Processing Record 37 of Set 10 | burnie
# Processing Record 38 of Set 10 | baiyin
# Processing Record 39 of Set 10 | champerico
# Processing Record 40 of Set 10 | kamenka
# Processing Record 41 of Set 10 | quzhou
# Processing Record 42 of Set 10 | lagos
# Processing Record 43 of Set 10 | belyy yar
# Processing Record 44 of Set 10 | tahta
# Processing Record 45 of Set 10 | kampene
# Processing Record 46 of Set 10 | puerto escondido
# Processing Record 47 of Set 10 | chengde
# Processing Record 48 of Set 10 | atasu
# Processing Record 49 of Set 10 | hlotse
# Processing Record 50 of Set 10 | vanimo
# Processing Record 1 of Set 11 | bay roberts
# Processing Record 2 of Set 11 | benguela
# Processing Record 3 of Set 11 | porto nacional
# Processing Record 4 of Set 11 | khrebtovaya
# Processing Record 5 of Set 11 | sidi ali
# Processing Record 6 of Set 11 | shenyang
# Processing Record 7 of Set 11 | vegueta
# Processing Record 8 of Set 11 | de-kastri
# Processing Record 9 of Set 11 | marienburg
# Processing Record 10 of Set 11 | khandagayty
# Processing Record 11 of Set 11 | pangai
# Processing Record 12 of Set 11 | ramban
# Processing Record 13 of Set 11 | kefalos
# Processing Record 14 of Set 11 | vale da amoreira
# Processing Record 15 of Set 11 | antakya
# Processing Record 16 of Set 11 | yarke pole
# Processing Record 17 of Set 11 | marystown
# Processing Record 18 of Set 11 | manokwari
# Processing Record 19 of Set 11 | mikhaylovka
# Processing Record 20 of Set 11 | viedma
# Processing Record 21 of Set 11 | senneterre
# Processing Record 22 of Set 11 | addanki
# Processing Record 23 of Set 11 | carbonia
# Processing Record 24 of Set 11 | westport
# Processing Record 25 of Set 11 | ziyang
# Processing Record 26 of Set 11 | port-de-paix
# City not found. Skipping...
# Processing Record 27 of Set 11 | heihe
# Processing Record 28 of Set 11 | tarime
# Processing Record 29 of Set 11 | monte carmelo
# Processing Record 30 of Set 11 | tunghsiao
# City not found. Skipping...
# Processing Record 31 of Set 11 | grand-lahou
# Processing Record 32 of Set 11 | rabo de peixe
# Processing Record 33 of Set 11 | zhanaozen
# Processing Record 34 of Set 11 | kangaatsiaq
# Processing Record 35 of Set 11 | batagay
# Processing Record 36 of Set 11 | adre
# Processing Record 37 of Set 11 | itanagar
# Processing Record 38 of Set 11 | spinus
# Processing Record 39 of Set 11 | azuqueca de henares
# Processing Record 40 of Set 11 | concepcion
# Processing Record 41 of Set 11 | portobelo
# Processing Record 42 of Set 11 | libreville
# Processing Record 43 of Set 11 | churachandpur
# Processing Record 44 of Set 11 | mazagao
# Processing Record 45 of Set 11 | sorvag
# City not found. Skipping...
# Processing Record 46 of Set 11 | tambun
# Processing Record 47 of Set 11 | bitkine
# Processing Record 48 of Set 11 | anar darreh
# City not found. Skipping...
# Processing Record 49 of Set 11 | csepreg
# Processing Record 50 of Set 11 | mont-dore
# Processing Record 1 of Set 12 | barkly west
# Processing Record 2 of Set 12 | labuan
# Processing Record 3 of Set 12 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 4 of Set 12 | tiarei
# Processing Record 5 of Set 12 | rio grande
# Processing Record 6 of Set 12 | tanabe
# Processing Record 7 of Set 12 | kautokeino
# Processing Record 8 of Set 12 | plettenberg bay
# Processing Record 9 of Set 12 | krasnyy yar
# Processing Record 10 of Set 12 | ketchenery
# City not found. Skipping...
# Processing Record 11 of Set 12 | zunyi
# Processing Record 12 of Set 12 | sainte-thecle
# Processing Record 13 of Set 12 | anito
# Processing Record 14 of Set 12 | tefe
# Processing Record 15 of Set 12 | ossora
# Processing Record 16 of Set 12 | walvis bay
# Processing Record 17 of Set 12 | santa isabel do rio negro
# Processing Record 18 of Set 12 | caceres
# Processing Record 19 of Set 12 | araguaina
# Processing Record 20 of Set 12 | lakes entrance
# Processing Record 21 of Set 12 | itaberaba
# Processing Record 22 of Set 12 | rungata
# City not found. Skipping...
# Processing Record 23 of Set 12 | mananjary
# Processing Record 24 of Set 12 | haines junction
# Processing Record 25 of Set 12 | shirokiy
# Processing Record 26 of Set 12 | russell
# Processing Record 27 of Set 12 | eureka
# Processing Record 28 of Set 12 | diego de almagro
# Processing Record 29 of Set 12 | putai
# Processing Record 30 of Set 12 | nadym
# Processing Record 31 of Set 12 | usinsk
# Processing Record 32 of Set 12 | taoudenni
# Processing Record 33 of Set 12 | araucaria
# Processing Record 34 of Set 12 | tahoua
# Processing Record 35 of Set 12 | goba
# Processing Record 36 of Set 12 | coreau
# Processing Record 37 of Set 12 | padang
# Processing Record 38 of Set 12 | ambalavao
# Processing Record 39 of Set 12 | tuy hoa
# Processing Record 40 of Set 12 | znamenskoye
# Processing Record 41 of Set 12 | riobamba
# Processing Record 42 of Set 12 | lokoja
# Processing Record 43 of Set 12 | jumla
# Processing Record 44 of Set 12 | kondinskoye
# Processing Record 45 of Set 12 | mustasaari
# Processing Record 46 of Set 12 | nelson bay
# Processing Record 47 of Set 12 | mahibadhoo
# Processing Record 48 of Set 12 | aykhal
# Processing Record 49 of Set 12 | qiyang
# Processing Record 50 of Set 12 | murgab
# Processing Record 1 of Set 13 | daru
# Processing Record 2 of Set 13 | gedo
# Processing Record 3 of Set 13 | half moon bay
# Processing Record 4 of Set 13 | crab hill
# City not found. Skipping...
# Processing Record 5 of Set 13 | bac lieu
# Processing Record 6 of Set 13 | takoradi
# Processing Record 7 of Set 13 | eyl
# Processing Record 8 of Set 13 | lemesos
# City not found. Skipping...
# Processing Record 9 of Set 13 | hearst
# Processing Record 10 of Set 13 | gorom-gorom
# Processing Record 11 of Set 13 | mount isa
# Processing Record 12 of Set 13 | amalapuram
# Processing Record 13 of Set 13 | paradise
# Processing Record 14 of Set 13 | isla mujeres
# Processing Record 15 of Set 13 | ocos
# Processing Record 16 of Set 13 | palaiokhora
# City not found. Skipping...
# Processing Record 17 of Set 13 | bedele
# Processing Record 18 of Set 13 | yarovoye
# Processing Record 19 of Set 13 | ouesso
# Processing Record 20 of Set 13 | egvekinot
# Processing Record 21 of Set 13 | yulara
# Processing Record 22 of Set 13 | lompoc
# Processing Record 23 of Set 13 | cabo rojo
# Processing Record 24 of Set 13 | san jeronimo
# Processing Record 25 of Set 13 | virginia beach
# Processing Record 26 of Set 13 | ketchikan
# Processing Record 27 of Set 13 | najran
# Processing Record 28 of Set 13 | zhangye
# Processing Record 29 of Set 13 | blyth
# Processing Record 30 of Set 13 | mazatlan
# Processing Record 31 of Set 13 | aksu
# Processing Record 32 of Set 13 | zyryanka
# Processing Record 33 of Set 13 | bridgetown
# Processing Record 34 of Set 13 | tual
# Processing Record 35 of Set 13 | cockburn harbour
# City not found. Skipping...
# Processing Record 36 of Set 13 | gonbad-e qabus
# Processing Record 37 of Set 13 | kudahuvadhoo
# Processing Record 38 of Set 13 | iquitos
# Processing Record 39 of Set 13 | cienfuegos
# Processing Record 40 of Set 13 | namtsy
# Processing Record 41 of Set 13 | yarmouth
# Processing Record 42 of Set 13 | thunder bay
# Processing Record 43 of Set 13 | skala fourkas
# Processing Record 44 of Set 13 | honningsvag
# Processing Record 45 of Set 13 | bartica
# Processing Record 46 of Set 13 | zhezkazgan
# Processing Record 47 of Set 13 | barentu
# Processing Record 48 of Set 13 | west bay
# Processing Record 49 of Set 13 | taltal
# Processing Record 50 of Set 13 | xinzhi
# Processing Record 1 of Set 14 | port hedland
# Processing Record 2 of Set 14 | herat
# Processing Record 3 of Set 14 | vila franca do campo
# Processing Record 4 of Set 14 | labuhan
# Processing Record 5 of Set 14 | syamzha
# Processing Record 6 of Set 14 | axim
# Processing Record 7 of Set 14 | mount gambier
# Processing Record 8 of Set 14 | podosinovets
# Processing Record 9 of Set 14 | sumenep
# Processing Record 10 of Set 14 | tiznit
# Processing Record 11 of Set 14 | yining
# Processing Record 12 of Set 14 | chara
# Processing Record 13 of Set 14 | sosnovo-ozerskoye
# Processing Record 14 of Set 14 | the valley
# Processing Record 15 of Set 14 | vao
# Processing Record 16 of Set 14 | biltine
# Processing Record 17 of Set 14 | ulety
# Processing Record 18 of Set 14 | kawana waters
# City not found. Skipping...
# Processing Record 19 of Set 14 | mianwali
# Processing Record 20 of Set 14 | kumbo
# Processing Record 21 of Set 14 | ximei
# Processing Record 22 of Set 14 | vila
# Processing Record 23 of Set 14 | salinopolis
# Processing Record 24 of Set 14 | dwarka
# Processing Record 25 of Set 14 | presidente medici
# Processing Record 26 of Set 14 | aripuana
# Processing Record 27 of Set 14 | gualaquiza
# Processing Record 28 of Set 14 | tallahassee
# Processing Record 29 of Set 14 | quelimane
# Processing Record 30 of Set 14 | marsh harbour
# Processing Record 31 of Set 14 | okhotsk
# Processing Record 32 of Set 14 | pine bluff
# Processing Record 33 of Set 14 | srednekolymsk
# Processing Record 34 of Set 14 | dasoguz
# Processing Record 35 of Set 14 | saint helens
# Processing Record 36 of Set 14 | gusau
# Processing Record 37 of Set 14 | khartoum
# Processing Record 38 of Set 14 | raudeberg
# Processing Record 39 of Set 14 | irkutsk
# Processing Record 40 of Set 14 | minsk
# Processing Record 41 of Set 14 | redcliffe
# Processing Record 42 of Set 14 | pedasi
# Processing Record 43 of Set 14 | ekhabi
# Processing Record 44 of Set 14 | dali
# Processing Record 45 of Set 14 | cambui
# Processing Record 46 of Set 14 | zlitan
# Processing Record 47 of Set 14 | brownwood
# Processing Record 48 of Set 14 | ayan
# Processing Record 49 of Set 14 | vavoua
# Processing Record 50 of Set 14 | toora-khem
# Processing Record 1 of Set 15 | batagay-alyta
# Processing Record 2 of Set 15 | thasra
# Processing Record 3 of Set 15 | santa barbara
# Processing Record 4 of Set 15 | marzuq
# Processing Record 5 of Set 15 | borskoye
# Processing Record 6 of Set 15 | beruwala
# Processing Record 7 of Set 15 | kropotkin
# Processing Record 8 of Set 15 | udachnyy
# Processing Record 9 of Set 15 | vikhorevka
# Processing Record 10 of Set 15 | winnemucca
# Processing Record 11 of Set 15 | da nang
# Processing Record 12 of Set 15 | phuket
# Processing Record 13 of Set 15 | arak
# Processing Record 14 of Set 15 | puerto del rosario
# Processing Record 15 of Set 15 | micheweni
# Processing Record 16 of Set 15 | aban
# Processing Record 17 of Set 15 | camiri
# Processing Record 18 of Set 15 | alotau
# City not found. Skipping...
# Processing Record 19 of Set 15 | waingapu
# Processing Record 20 of Set 15 | pietermaritzburg
# Processing Record 21 of Set 15 | zemio
# Processing Record 22 of Set 15 | grand centre
# City not found. Skipping...
# Processing Record 23 of Set 15 | naze
# Processing Record 24 of Set 15 | antsohihy
# Processing Record 25 of Set 15 | nhulunbuy
# Processing Record 26 of Set 15 | cap-haitien
# Processing Record 27 of Set 15 | petropavlovsk-kamchatskiy
# Processing Record 28 of Set 15 | belle glade
# Processing Record 29 of Set 15 | novaya lyalya
# Processing Record 30 of Set 15 | sayyan
# Processing Record 31 of Set 15 | omboue
# Processing Record 32 of Set 15 | worland
# Processing Record 33 of Set 15 | san matias
# Processing Record 34 of Set 15 | cascais
# Processing Record 35 of Set 15 | timra
# Processing Record 36 of Set 15 | tecpan
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Tally the number of cities in the city_data array of dictionaries
len(city_data)
# Out:
# 673

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0    Saint George      US  37.1041 -113.5841     77.47        30           1
# 1        La Palma      US  33.8464 -118.0467     96.12        19           0
# 2        Bilibino      RU  68.0546  166.4372      8.71        92         100
# 3          Durres      AL  41.3231   19.4414     51.98        77          82
# 4  Port Macquarie      AU -31.4333  152.9167     66.88        47           0
# 5         Mataura      NZ -46.1927  168.8643     48.20        99         100
# 6     Tuktoyaktuk      CA  69.4541 -133.0374     21.20        79          90
# 7  Saint-Philippe      RE -21.3585   55.7679     74.75        83          96
# 8           Pisco      PE -13.7000  -76.2167     69.85        68           0
# 9       Cape Town      ZA -33.9258   18.4232     66.09        72           0
#
#    Wind Speed Current Description
# 0        1.99           clear sky
# 1        5.01           clear sky
# 2        6.08     overcast clouds
# 3        5.53       broken clouds
# 4       10.45           clear sky
# 5        1.05     overcast clouds
# 6       16.11          light snow
# 7       10.92     overcast clouds
# 8        9.22           clear sky
# 9        3.00           clear sky

# %%
# Export the DataFrame as a CSV file, and save it as WeatherPy_Database.csv in the Weather_Database folder
# Create the output file (CSV).
output_data_file = "../Weather_Database/WeatherPy_Database.csv"

# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
